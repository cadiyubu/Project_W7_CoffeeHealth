# %% [markdown]
# # Load & Clean Data
# **Goal**: Ingest raw data, assess quality, apply cleaning/feature engineering, export `data_cleaned.csv`.
#
# ---

# %%
#import libraries, functions, etc

# %% [markdown]
# ## 1. Load Raw Data

# %%
# df = load_raw_data(cfg['paths']['raw_data'])

# %% [markdown]
# ## 2. Initial Exploration

# %%
# summarise_dataframe(df)

# %% [markdown]
# ## 3. Cleaning
# > Document each decision: why you drop/impute/encode.

# %%
# [XXX] cleaning steps here

# %% [markdown]
# ## 4. Feature Engineering
# > Create new features, encode categoricals, handle outliers.

# %%
# [XXX] feature engineering steps here

# %% [markdown]
# ## 5. Export Clean Data

# %%
# df_clean.to_csv(cfg['paths']['clean_data'], index=False)
# print('Saved:', cfg['paths']['clean_data'])
